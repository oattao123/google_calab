# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])
plt.xlim(1,6)
plt.ylim(1,7)
left,right = plt.xlim()
print(left,right)
plt.xlabel("x label")
plt.ylabel("y label")
plt.title("First")
plt.show()
