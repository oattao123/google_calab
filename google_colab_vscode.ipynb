# %%
# !pip install -q colabcode

# %%
from colabcode import ColabCode

# %%
ColabCode(port=2333,password="helloworld")
# Out:
# Code Server can be accessed on: NgrokTunnel: "https://6e32163866e0.ngrok.io" -> "http://localhost:2333"
# [2021-08-20T11:38:32.543Z] info  code-server 3.10.2 387b12ef4ca404ffd39d84834e1f0776e9e3c005
# [2021-08-20T11:38:32.544Z] info  Using user-data-dir ~/.local/share/code-server
# [2021-08-20T11:38:32.561Z] info  Using config file ~/.config/code-server/config.yaml
# [2021-08-20T11:38:32.561Z] info  HTTP server listening on http://127.0.0.1:2333
# [2021-08-20T11:38:32.561Z] info    - Authentication is enabled
# [2021-08-20T11:38:32.561Z] info      - Using password from $PASSWORD
# [2021-08-20T11:38:32.561Z] info    - Not serving HTTPS
