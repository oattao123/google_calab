# %%
pip install thai_sentiment

# %%
 from thai_sentiment import get_sentiment
print(get_sentiment('ดีมาก'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-7432f3f68350> in <module>()
# ----> 1 from thai_sentiment import get_sentiment
#       2 print(get_sentiment('ดีมาก'))
#
# /usr/local/lib/python3.7/dist-packages/thai_sentiment/__init__.py in <module>()
#       5 from .architecture import NbSvmClassifier
#       6 from sklearn.feature_extraction.text import TfidfVectorizer
# ----> 7 from pythainlp.ulmfit import process_thai
#       8 import pickle
#       9 import urllib.request
#
# /usr/local/lib/python3.7/dist-packages/pythainlp/ulmfit/__init__.py in <module>()
#      38 ]
#      39
# ---> 40 from pythainlp.ulmfit.core import (
#      41     THWIKI_LSTM,
#      42     document_vector,
#
# /usr/local/lib/python3.7/dist-packages/pythainlp/ulmfit/core.py in <module>()
#      10 from pythainlp.corpus import get_corpus_path
# ...
