# %% [markdown]
# สวัสดี

# %%
# Program to generate a random number between 0 and 9

# importing the random module
import random

print(random.randint(0,9))
# Out:
# 8

# %%
import pylab as py 
py.scatter([2,2,3],[1,2,3])

# %%
from urllib.request import urlopen 
from PIL import Image 
url = 'https://files.vogue.co.th/uploads/COVVERNN9.jpg'
a = 'https://www.techtalkthai.com/wp-content/uploads/2016/02/python_techtalkthai_banner.png'
x = Image.open(urlopen(a))
x
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=600x300 at 0x7F81C3755F98>

# %% [markdown]
# # ส่วนใหม่

# %%
# !pip install botnoi==0.2.1
# Out:
# ...
#      |████████████████████████████████| 16.0MB 269kB/s
# ...

# %%
import botnoi as bn

# %%
def stutter(word):
 return word[0:2] + ".. " + word[0:2] + ".. " + word + "?"

stutter("enthusiastic")
# Out:
# 'en.. en.. enthusiastic?'
